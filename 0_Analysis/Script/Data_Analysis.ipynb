# %% [markdown]
# ##### Libraries Import

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##### Read File

# %%
df = pd.read_csv('D:/Data_Science/0_Analysis/1_RawData/Online Sales Data.csv')

# %%
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
df.describe(include='all').T
# Out:
#                   count unique                          top freq        mean  \
# Transaction ID    240.0    NaN                          NaN  NaN     10120.5
# Date                240    240                   2024-01-01    1         NaN
# Product Category    240      6                  Electronics   40         NaN
# Product Name        240    232  Dyson Supersonic Hair Dryer    2         NaN
# Units Sold        240.0    NaN                          NaN  NaN    2.158333
# Unit Price        240.0    NaN                          NaN  NaN  236.395583
# Total Revenue     240.0    NaN                          NaN  NaN  335.699375
# Region              240      3                North America   80         NaN
# Payment Method      240      3                  Credit Card  120         NaN
#
#                          std      min       25%      50%       75%      max
# Transaction ID      69.42622  10001.0  10060.75  10120.5  10180.25  10240.0
# ...

# %% [markdown]
# There is no dupplicate colone in the dataset

# %% [markdown]
# ##### Check Null Values

# %%
pd.isnull(df).value_counts()
# Out:
# Transaction ID  Date   Product Category  Product Name  Units Sold  Unit Price  Total Revenue  Region  Payment Method
# False           False  False             False         False       False       False          False   False             240
# Name: count, dtype: int64

# %% [markdown]
# There is no null value in the dataset

# %% [markdown]
# ##### Check and Transform Data Type

# %%
df.dtypes
# Out:
# Transaction ID        int64
# Date                 object
# Product Category     object
# Product Name         object
# Units Sold            int64
# Unit Price          float64
# Total Revenue       float64
# Region               object
# Payment Method       object
# dtype: object

# %% [markdown]
# I will transform two data. The date will become a dateformat and the Transaction ID a string. We will probably need the date but the ID will not be use for operation. From that, it's better if it become a string.

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')
df['Transaction ID'] = df['Transaction ID'].astype(str)

# %%
df.dtypes
# Out:
# Transaction ID              object
# Date                datetime64[ns]
# Product Category            object
# Product Name                object
# Units Sold                   int64
# Unit Price                 float64
# Total Revenue              float64
# Region                      object
# Payment Method              object
# dtype: object

# %% [markdown]
# ##### Dataset Save

# %%
df.to_csv('D:/Data_Science/0_Analysis/2_PreparedData/Cleanned_Online_Sales_Data.csv', index=False, sep=';')

# %% [markdown]
# ### Data Analysis

# %% [markdown]
# In this part, I will use the previous dataset on Tableau Desktop.
# Context is :
# I am hiried by a little company who made international sell. They notice a loss of profit within the last months. They want me to analyse their evolution and determine why they profit drop.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# We can notice that this company made 50% less profit between Janaury and August. The drop begin in May. May is a great period to buy stuff such as clothes right before the summer. The sell should grown up and the profit with it but it's not the case.
# Why ?
# Let's analyze the other Data to determine we don't made more profit.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Thank to this map, we can notice that the most important market is Asia and Europa is the less one. North America made great sell also. But the sell don't really show how many money we earn from a region. Curently the problem might come from Europe Region but let's check own monney we had made from all th regions.

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png) ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# With this graphs, we can notice that the 3 products that sell the less are Elctronics, Home Appliances and Beauty Products. On the other hand, Electronics and Home Appliance are the most profit products.
# Futhermore, we can notice that a big part of monthly sell are made by books but they represent the worst profit overall. Something that is not in the dataset and wold be great to see, is the cost of each product. With this, we could see wich product is the more profitable between the craft or made and the sell. In the case of Books are the more profitable, it can be great to keep and expanse this market.
# About Beauty Products, they made poor sales and poor profit. The trust is hard to obtain for the customers espacially with Beauty Products. They prefer to choose detect company to this product. So, it would be logical to abandon this market as we can't pass the competition.

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# In accord with what we observe until right now, Europen market is the most impactfull on our profit on this is the only market for for Beauty Products. They represent 44% of the sales but only 10% of the profit. On the othre side, Home Appliances is only sales in Europe also but are more profitable and have a remarkable profit overall. Adandon the Beauty Products could be a nice choice but we have to stay on Europen market.
# If we want to optimize more, we can talk about Books who are present only on North America market. They represent 36% of the sales for only 5% of profit. Despite what we said earlier, this market is not profitable enough to be a good market.
# By ignoring those two side, we can optimize our ressources to other market that are more profitable and save some money. Or, we can keep the Book market but we have to rise up the price to make more profit.

# %% [markdown]
# ![image-3.png](attachment:image-3.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Concerning payement mode, the most use and the most profitable is debit card wich is use in Asia and North America. Extend this to Europe could be a really good strategy as a lot of people have one too. Related to our observation, Paypal is the msot use in Europe and they made especially big check has they buy generally Home Appliances product. Probably, they think this is more safe for this kind of use. Considering this mode for other Region use to big payement such as North America with Electronics product could be a right thing.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# After all of this, we can say that the most important region is North America in term of profit and Asia in terms of sales. Concider rise up price in Asia could be an interessing choice, remove Beauty Products also is a great as they are not profitable enough like Books. Also generalize all payement mode to all region is a way to make more profit.
